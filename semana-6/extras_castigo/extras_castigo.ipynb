# %% [markdown]
# #### Ejercicio 1: Área de un triángulo
# Escribe un programa en Python que aplique el modelo Entrada-Proceso-Salida para calcular el área de un triángulo (`area = (base * altura) / 2`), usando `input()`, `float()` y `print()`.
# **Entrada:** `base = 8`, `altura = 5`
# **Salida:** `El área del triángulo es: 20.0`

# %%
base = float(input("Dame la medida de la base del triangulo: "))
altura = float(input("Dame la medida de la altura del triangulo: "))

area = (base*altura)/2

print(f"El area del triangulo es: {area}")
# Out:
# El area del triangulo es: 20.0

# %% [markdown]
# #### Ejercicio 2: Conversión de Celsius a Fahrenheit
# Escribe un programa en Python que pida una temperatura en grados Celsius y la convierta a Fahrenheit (`F = C * 9/5 + 32`).
# **Entrada:** `celsius = 30`
# **Salida:** `30 grados Celsius equivalen a 86.0 grados Fahrenheit`

# %%
celsius = float(input("Ingresa los grados celsius a convertir: "))

fahrenheit = celsius * 9/5 + 32

print(f"{celsius} grados celsius equivalen a {fahrenheit} graados fahrenheit")
# Out:
# 30 grados celsius equivalen a 86.0 graados fahrenheit

# %% [markdown]
# #### Ejercicio 3: Interés simple (antes en PSeInt)
# Escribe un programa en Python que pida capital, tasa y tiempo, y calcule el interés simple (`interes = capital * (tasa / 100) * tiempo`).
# **Entrada:** `capital = 2000`, `tasa = 6`, `tiempo = 2`
# **Salida:** `El interés simple es: 240.0`

# %%
capital = float(input("Ingresa la capital: "))
tasa = float(input("Ingresa la tasa: "))
tiempo = float(input("Ingresa la capital: "))

interes = capital * (tasa/100) * tiempo

print(f"La tasa de interes simple es: {interes}")
# Out:
# La tasa de interes simple es: 240.0

# %% [markdown]
# #### Ejercicio 4: Precedencia de operadores (antes de análisis teórico)
# Escribe un programa en Python que calcule `4 * 3 + 10 // 3 - 8 % 5`, muestre el resultado y **imprima el orden de evaluación aplicado** (`12 + 3 - 3`).
# **Salida:**
# ```
# 4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 = 12
# ```

# %%
r = 4 * 3 + 10 // 3 - 8 % 5

print("(4 * 3) + (10 // 3) - (8 % 5) = ?")
print("12 + 3 - 3 = ?")
print(f"12 + 3 - 3 = {r}")
# Out:
# (4 * 3) + (10 // 3) - (8 % 5) = ?
# 12 + 3 - 3 = ?
# 12 + 3 - 3 = 12

# %% [markdown]
# #### Ejercicio 5: Casting tras `input()` (antes de análisis teórico)
# Escribe un programa en Python que pida un número con `input()`, demuestre que devuelve `str` (`type()`), intente `x + 1` dentro de `try-except` capturando `TypeError`, y finalmente haga `int(x)` para sumar y obtener el resultado correcto.
# **Entrada:** `"25"`
# **Salida:** `x es tipo str`, `x + 1 genera TypeError`, `int(x) + 1 = 26`

# %%
try: 
    x = input("Dame un numero: ")
    r = x+1
    print(r)
except TypeError:
    print(f"x es tipo {type(x).__name__}, x+1 genera TypeError", end=", ")
    x = int(x)
    print(f"int({x})+1 = {x+1}")
# Out:
# x es tipo str, x+1 genera TypeError, int(25)+1 = 26

# %% [markdown]
# #### Ejercicio 6: Conversión de horas a segundos
# Crea un programa que pida una cantidad de horas (`float`) y la convierta a segundos (1 hora = 3600 segundos), mostrando el resultado formateado.
# **Entrada:** `3`
# **Salida:** `3 horas equivalen a 10800 segundos`

# %%
horas = float(input("Dame una cantidad de horas a convertir: "))

segundos = horas * 3600

print(f"{horas} horas equivale a {segundos} segundos")
# Out:
# 3.0 horas equivale a 10800.0 segundos

# %% [markdown]
# #### Ejercicio 7: Descuento del 15% con f-strings
# Crea un programa que pida el precio de un artículo y aplique un 15% de descuento, mostrando el monto del descuento y el precio final con dos decimales usando f-strings.
# **Entrada:** `460`
# **Salida:**
# ```
# Descuento (15%): $69.00
# Precio final: $391.00
# ```

# %%
art = float(input("Dame el precio del articulo: "))

des = art * .15

print(f"Descuento(15%): ${des}")
print(f"Precio final: ${art-des}")
# Out:
# Descuento(15%): $69.0
# Precio final: $391.0

# %% [markdown]
# #### Ejercicio 8: Número par o impar
# **Entrada:** `17` → **Salida:** `17 es un número impar`

# %%
num = int(input("Dame un numero entero: "))

if(num % 2 == 0):
    print(f"{num} es un numero par")
else:
    print(f"{num} es un numero impar")
# Out:
# 17 es un numero impar

# %% [markdown]
# #### Ejercicio 9: Mayor de tres números
# **Entrada:** `12`, `45`, `23` → **Salida:** `El mayor de los tres números es: 45`

# %%
num_1 = int(input("Dame el primer numero: "))
num_2 = int(input("Dame el segundo numero: "))
num_3 = int(input("Dame el tercer numero: "))

if(num_1 > num_2 and num_1 > num_3):
    print(f"El mayor de los tres numeros es: {num_1}")
elif(num_2 > num_1 and num_2 > num_3):
    print(f"El mayor de los tres numeros es: {num_2}")
else:
    print(f"El mayor de los tres numeros es: {num_3}")
# Out:
# El mayor de los tres numeros es: 45

# %% [markdown]
# #### Ejercicio 10: Suma acumulada con `while`
# Pide números mientras sean distintos de `0` (el `0` termina el ciclo y no se suma).
# **Entrada:** `5`, `8`, `2`, `0` → **Salida:** `La suma de los números es: 15`

# %%
cic = 1
sum = 0 
while cic != 0:
    cic = float(input("Dame un numero a sumar: "))
    sum += cic

print(f"La suma de los números es: {sum}")
# Out:
# La suma de los números es: 15.0

# %% [markdown]
# #### Ejercicio 11: Tabla de multiplicar con `for`
# **Entrada:** `6` → **Salida:** tabla del 6 del `6 x 1 = 6` al `6 x 10 = 60`

# %%
num = int(input("Dame el numero del cual quieres su tabla: "))

for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# #### Ejercicio 12: Suma de pares del 1 al 20 con `for` y `continue`
# **Salida:** `La suma de los números pares del 1 al 20 es: 110`

# %%
suma = 0

for i in range(1, 21):
    if i % 2 != 0:
        continue
    suma += i

print(f"La suma de los números pares del 1 al 20 es: {suma}")
# Out:
# La suma de los números pares del 1 al 20 es: 110

# %% [markdown]
# #### Ejercicio 13: Suma de una lista con función que regresa valor (sin `sum()`)
# **Entrada:** `[10, 20, 30, 40]` → **Salida:** `La suma de los elementos es: 100`

# %%
def sumar_lista(lista):
    total = 0
    for numero in lista:
        total += numero
    return total

numeros = [10, 20, 30, 40]
print(f"La suma de los elementos es: {sumar_lista(numeros)}")
# Out:
# La suma de los elementos es: 100

# %% [markdown]
# #### Ejercicio 14: Máximo de una lista con función que regresa valor (sin `max()`)
# **Entrada:** `[7, 3, 9, 2]` → **Salida:** `El elemento máximo es: 9`

# %%
def maximo_list(lista):
    maximo = lista[0]
    for numero in lista:
        if numero > maximo:
            maximo = numero
    return maximo

numeros = [7, 3, 9, 2]
print(f"El elemento máximo es: {maximo_list(numeros)}")
# Out:
# El elemento máximo es: 9

# %% [markdown]
# #### Ejercicio 15: Matriz y suma de la diagonal principal
# **Entrada:** `[[1,2,3],[4,5,6],[7,8,9]]` → **Salida:** `La suma de la diagonal principal es: 15`

# %%
matriz = [[1, 2, 3],
          [4, 5, 6],
          [7, 8, 9]]

suma_diagonal = 0

for i in range(len(matriz)):
    suma_diagonal += matriz[i][i]

print(f"La suma de la diagonal central es: {suma_diagonal}")
# Out:
# La suma de la diagonal principal es: 15

# %% [markdown]
# #### Ejercicio 16: Promedio con función que no regresa valor
# **Entrada:** `[8, 9, 10, 7]` → **Salida:** `El promedio es: 8.50`

# %%
def sumar_lista(lista):
    total = 0
    for numero in lista:
        total += numero
    return total

def calcular_promedio(lista):
    promedio = sumar_lista(calificaciones) / len(lista)
    print(f"El promedio es: {promedio:.2f}")

calificaciones = [8, 9, 10, 7]

calcular_promedio(calificaciones)
# Out:
# El promedio es: 8.50

# %% [markdown]
# #### Ejercicio 17: Invertir una lista con slicing
# **Entrada:** `[1, 2, 3, 4, 5]` → **Salida:** `Lista invertida: [5, 4, 3, 2, 1]`

# %%
lista = [1, 2, 3, 4, 5]
lista_invertida = lista[::-1]
print(f"Lista invertida: {lista_invertida}")
# Out:
# Lista invertida: [5, 4, 3, 2, 1]

# %% [markdown]
# #### Ejercicio 18: Factorial con función recursiva
# **Entrada:** `5` → **Salida:** `El factorial de 5 es: 120`

# %%
def calcular_factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * calcular_factorial(n - 1)

numero = 5

print(f"El factorial de {numero} es: {calcular_factorial(numero)}")
# Out:
# El factorial de 5 es: 120

# %% [markdown]
# #### Ejercicio 19: Tupla: acceso y suma con función
# **Entrada:** `(4, 8, 15, 16, 23, 42)` → **Salida:**
# ```
# El tercer elemento es: 15
# La suma de la tupla es: 108
# ```

# %%
def sumar_tupla(tupla):
    total = 0
    for numero in tupla:
        total += numero
    return total

datos = (4, 8, 15, 16, 23, 42)

print(f"El tercer elemento es: {datos[2]}")
print(f"La suma de la tupla es: {sumar_tupla(datos)}")
# Out:
# El tercer elemento es: 15
# La suma de la tupla es: 108

# %% [markdown]
# #### Ejercicio 20: Diccionario: buscar teléfono de un contacto
# **Entrada:** `Beto` → **Salida:** `El teléfono de Beto es: 5555678`

# %%
agenda = {"Beto": "5555678", "Alex": "456742"}

contacto = "Beto"

print(f"El teléfono de {contacto} es: {agenda[contacto]}")
# Out:
# El teléfono de Beto es: 5555678

# %% [markdown]
# #### Ejercicio 21: Diccionario de calificaciones y promedios
# **Entrada:** `{"Ana": [8, 9, 10], "Beto": [7, 7, 8]}` → **Salida:**
# ```
# Ana: 9.00
# Beto: 7.33
# ```

# %%
alumnos = {"Ana": [8, 9, 10], "Beto": [7, 7, 8]}

for nombre, notas in alumnos.items():
    promedio = sum(notas) / len(notas)
    print(f"{nombre}: {promedio:.2f}")
# Out:
# Ana: 9.00
# Beto: 7.33

# %% [markdown]
# #### Ejercicio 22: Excepción de división entre cero
# **Entrada:** `10`, `0` → **Salida:** `Error: No se puede dividir entre cero.`

# %%
try:
    dividendo = int(input("Dame un numero a dividir"))
    divisor = int(input("Dame un numero divisor"))
    resultado = dividendo / divisor
    print(resultado)
except ZeroDivisionError:
    print("Error: No se puede dividir entre cero.")
# Out:
# Error: No se puede dividir entre cero.

# %% [markdown]
# #### Ejercicio 23: Excepción de valor no numérico
# **Entrada:** `"abc"` → **Salida:** `Error: Debes ingresar un número entero.`

# %%
try:
    numero = int(input("Dame un numero de 3 digitos"))
except ValueError:
    print("Error: Debes ingresar un número entero.")
# Out:
# Error: Debes ingresar un número entero.

# %% [markdown]
# #### Ejercicio 24: Contar palabras de un string
# **Entrada:** `"Python es un lenguaje de programacion"` → **Salida:** `El mensaje tiene 6 palabras.`

# %%
mensaje = "Python es un lenguaje de programacion"
palabras = mensaje.split()
print(f"El mensaje tiene {len(palabras)} palabras.")
# Out:
# El mensaje tiene 6 palabras.

# %% [markdown]
# #### Ejercicio 25: Longitud, mayúsculas y reemplazo de un string
# **Entrada:** `"aprende python"` → **Salida:**
# ```
# Longitud: 14
# En mayúsculas: APRENDE PYTHON
# Reemplazo: aprende programacion
# ```

# %%
texto = "aprende python"

print(f"Longitud: {len(texto)}")
print(f"En mayúsculas: {texto.upper()}")
print(f"Reemplazo: {texto.replace('python', 'programacion')}")
# Out:
# Longitud: 14
# En mayúsculas: APRENDE PYTHON
# Reemplazo: aprende programacion
