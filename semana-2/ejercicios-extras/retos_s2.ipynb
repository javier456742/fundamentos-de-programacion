# %% [markdown]
# ### Extra 1: Control de aforo con break y continue (while)
# **Enunciado:** Crea un programa que procese visitantes del museo con un ciclo `while`. Por cada visitante se captura el costo de su boleto ($0 para menores de 3 años, $30 para 3 a 17 años, $45 para mayores de 18). Si el boleto es gratis, muestra "Menor de 3 años, sin cargo" y continúa con el siguiente visitante (usa `continue`). Si el total acumulado alcanza o supera $100, detén el ciclo con `break` y muestra el total.

# %%
visit = int(input("Cuantas personas van a ingresar?"))

t_bol=0

for i in range(1, visit+1):

    edad = int(input(f"Ingresa la edad de la persona {i}: "))

    if(t_bol >= 100):
        break

    if(edad <= 3):
        print("Menor de 3 años, sin cargo")
    elif(edad <= 17):
        t_bol +=30
    else:
        t_bol +=45

print(t_bol)
# Out:
# Menor de 3 años, sin cargo
# 135

# %% [markdown]
# ### Extra 2: Estadística de visitantes con for
# **Enunciado:** Crea un programa que pida el número total de visitantes y, con un ciclo `for`, capture la edad de cada uno. Debe contar cuántos son adultos (18 años o más) y calcular el promedio de edad de todos los visitantes, mostrando ambos resultados con dos decimales.

# %%
visit = int(input("Cuantas personas van a ingresar?"))

n_mayores = 0
n_edades = 0

for i in range(1, visit+1):

    edad = int(input(f"Ingresa la edad de la persona {i}: "))

    if(edad > 0):
        n_edades += edad

    if(edad >= 18):
        n_mayores += 1

prom_edades = n_edades/visit
print(f"El promedio de edad de los visitantes es: {prom_edades:.2f}")
print(f"El numero de mayores de edad es: {n_mayores}")
# Out:
# El promedio de edad de los visitantes es: 21.33
# El numero de mayores de edad es: 2

# %% [markdown]
# ### Extra 3: Depuración de un cobro con PDB
# **Enunciado:** El siguiente código pretende calcular el precio final de un boleto de $45 con el descuento del adulto mayor (12%) pero contiene un error de lógica. Inserta `pdb.set_trace()` para rastrear las variables, identifica el error y escribe la versión corregida.
# ```python
# precio = 45
# descuento = 12
# total = precio - descuento
# print(f"Total: ${total:.2f}")
# ```

# %%
import pdb

precio = 45
descuento = 45*.12

pdb.set_trace()

total = precio - descuento

print(f"Total: ${total:.2f}")
# Out:
# > c:\users\francisco\appdata\local\temp\ipykernel_4108\7289894.py(6)<module>()
#
# 45
# *** Argument is required for this command
#       Usage: p expression
# *** Argument is required for this command
#       Usage: p expression
# 5.3999999999999995
# 5.3999999999999995
# *** Argument is required for this command
#       Usage: p expression
# *** NameError: name 'total' is not defined
# *** Argument is required for this command
#       Usage: p expression
# *** NameError: name 'total' is not defined
# --Return--
# None
# > c:\users\francisco\appdata\local\temp\ipykernel_4108\7289894.py(6)<module>()
#
#     [... skipped 1 hidden frame(s)]
#
# > c:\users\francisco\appdata\local\python\pythoncore-3.14-64\lib\site-packages\ipython\core\interactiveshell.py(3778)run_code()
#    3776             finally:
#    3777                 # Reset our crash handler in place
# -> 3778                 sys.excepthook = old_excepthook
#    3779         except SystemExit as e:
#    3780             if result is not None:
#
#     [... skipped 1 hidden frame(s)]
#
# > c:\users\francisco\appdata\local\python\pythoncore-3.14-64\lib\site-packages\ipython\core\interactiveshell.py(3799)run_code()
#    3797             self.showtraceback(running_compiled_code=True)
#    3798         else:
# -> 3799             outflag = False
#    3800         return outflag
#    3801
#
#     [... skipped 1 hidden frame(s)]
#
# > c:\users\francisco\appdata\local\python\pythoncore-3.14-64\lib\site-packages\ipython\core\interactiveshell.py(3800)run_code()
#    3798         else:
#    3799             outflag = False
# -> 3800         return outflag
#    3801
#    3802     # For backwards compatibility
#
#     [... skipped 1 hidden frame(s)]
#
# Internal StopIteration: False
# > c:\users\francisco\appdata\local\python\pythoncore-3.14-64\lib\site-packages\ipython\core\interactiveshell.py(3715)run_ast_nodes()
#    3713                     code = compiler(mod, cell_name, mode)
#    3714                     asy = compare(code)
# -> 3715                 if await self.run_code(code, result, async_=asy):
#    3716                     return True
#    3717
#
# > c:\users\francisco\appdata\local\python\pythoncore-3.14-64\lib\site-packages\ipython\core\interactiveshell.py(3703)run_ast_nodes()
#    3701                 to_run.append((node, "single"))
#    3702
# -> 3703             for node, mode in to_run:
#    3704                 if mode == "exec":
#    3705                     mod = Module([node], [])

# %% [markdown]
# ### Extra 4: Pirámide de asteriscos con for
# **Enunciado:** Crea un programa que pida la altura de una pirámide y la dibuje con asteriscos usando ciclos `for` anidados y el parámetro `end` de `print`.

# %%
alt = int(input("dame la altura de una piramide: "))

for i in range(1, alt=1):

    alt = "*"
    print(f"{alt}")
