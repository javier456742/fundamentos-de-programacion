# %% [markdown]
# # Semana 7

# %%
archivo = open("saludo.txt", mode="w")
archivo.write("Si se puede escribir desde python")
archivo.close()
print("se ha escrito en el archivo.txt")
# Out:
# se ha escrito en el archivo.txt

# %%
archivo = open("saludo.txt", mode="a")
archivo.write("Esto es una tercera linea\n")
archivo.close()
print("se ha escrito en el archivo.txt")
# Out:
# se ha escrito en el archivo.txt

# %%
archivo = open("notas.txt", mode="w")
archivo.write("Esto es una primera linea\n")
archivo.write("Esto es una segunda linea\n")
archivo.write("Esto es una tercera linea\n")
archivo.close()

# %%
with open("bitacora.txt", mode="w") as archivo:
    archivo.write("Esto es una primera linea\n")
    archivo.write("Esto es una segunda linea\n")
    archivo.write("Esto es una tercera linea\n")

with open("bitacora.txt", mode="a") as archivo:
    archivo.write("Esto es una cuarta linea\n")

# %%
nombre = input("Ingrese su nombre")
edad = input("Ingrese su edad ")

with open("datos_usuario", mode="w") as archivo:
    archivo.write(f"Nombre {nombre}, edad {edad}")

print("xd")
# Out:
# xd

# %% [markdown]
# # Lectura

# %%
with open("bitacora.txt", mode="r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# Esto es una primera linea
# Esto es una segunda linea
# Esto es una tercera linea
# Esto es una cuarta linea
